# %% [markdown]
#  # 🌌 Stars Analysis and Prediction 🌠
#
#   🔭 Mapping Stars with Intelligence

# %% [markdown]
# <div >
#   <img src="https://res.cloudinary.com/dhditogyd/image/upload/v1725305778/pexels-alex-andrews-271121-3805983_nwekq9.jpg" width="100%" height=" 800%;"/>
# </div>
#
# ---

# %% [markdown]
# Author: [Muhammad Faizan](https://www.linkedin.com/in/mrfaizanyousaf/)
#
# <div >
#   <img src="https://res.cloudinary.com/dk0hm8t43/image/upload/v1723543716/Faizan/cxhm4yhcpmponfjgjfct.jpg" width="20%" height=" 20%;"/>
# </div>
#
# <br>
# <br>
#
# <div style="
#     padding: 20px;
#     border-radius: 10px;
#     color: #00FFFF;
#     font-size: 24px;
#     text-shadow: 0 0 10px #00FFFF, 0 0 20px #00FFFF, 0 0 30px #00FFFF, 0 0 40px #00FFFF;
# ">
#     <h3> Muhammad Faizan 👨‍🚀</h3>
# </div>
#
# 🎓 **3rd Year BS Computer Science** student at the **University of Agriculture, Faisalabad**
# 💻 Enthusiast in **Machine Learning, Data Engineering, and Data Analytics**
#
#
# ### 🌐 Connect with Me
#
# [Kaggle](https://www.kaggle.com/faizanyousafonly/) | [LinkedIn](https://www.linkedin.com/in/mrfaizanyousaf/) | [GitHub](https://github.com/faizan-yousaf/)
#
#
#
#
# ### 💬 Contact Me
# - **Email:** faizanyousaf815@gmail.com
# - **WhatsApp:** [+92 306 537 5389](https://wa.me/923065375389)
#
#
# 🔗 **Let’s Collaborate:**
# I'm always open to queries, collaborations, and discussions. Let's build something amazing together!

# %% [markdown]
# <div style="
#     =
#     padding: 20px;
#     text-align: center;
#     border-radius: 10px;
#     color: #00FFFF;
#     font-size: 24px;
#     text-shadow: 0 0 10px #00FFFF, 0 0 20px #00FFFF, 0 0 30px #00FFFF, 0 0 40px #00FFFF;
# ">
#     <h1> Meta-Data (About Dataset) 🛰</h1>
# </div>

# %% [markdown]
# **Context**:
# * This dataset offers a `detailed collection of information` about `various stars` in our galaxy. It includes key characteristics such as stellar temperature, luminosity, radius, and spectral class, providing a comprehensive view of different types of stars.
#
# * The data is structured to help astronomers, researchers, and enthusiasts explore the `relationships` between these `stellar attributes` and better understand the `diversity of stars` in the universe. Each entry in the dataset represents a `unique star`, with `data sourced from astronomical surveys and observations`.
#
# * Whether you're interested in studying the life cycle of stars, their physical properties, or just exploring the vastness of space, this dataset serves as a valuable resource for all things celestial. Dive in and discover the wonders of the stars!
#
# **Content**:
#
# *Column Descriptions*:
#
# * `Name:` A unique identifier for each star.
# * `Distance (ly):` The distance of the star from Earth in light-years.
# * `Temperature (K):` The surface temperature of the star in Kelvin.
# * `Luminosity (L/Lo):` The luminosity of the star compared to that of the Sun.
# * `Radius (R/Ro):` The radius of the star relative to the Sun's radius.
# * `Spectral Class:` The star’s classification based on its spectral characteristics (e.g., O, B, A, F, G, K, M).
#
#
#
# **Acknowledgements**
# *Creator*:
#
# * Waqar Ali, Data Scientist, Kaggle Dataset Expert, Lahore, Punjab, Pakistan. [Link](https://www.kaggle.com/waqi786)

# %% [markdown]
# **Aims and Objectives**: 🎯
#
# We will fill this after doing the EDA and Data Preprocessing.

# %% [markdown]
# **Work Flow of this project:** 👨‍🚀
#
#
# 1. `Importing Necessary Libraries`
#
# 2. `Loading the Dataset`
#
# 3. `Exploratory Data Analysis (EDA)`
#     * Understanding the Data Structure
#     * Checking for Missing Values
#     * Descriptive Statistics
#     * Data Visualization
#
# 4. `Data Preprocessing`
#     * Handling Missing Values (if any)
#     * Encoding Categorical Variables (if any)
#     * Feature Scaling
#
# 5. `Building the Classification Model`
#     * Splitting the Data into Training and Testing Sets
#     * Choosing the Right Algorithm
#     * Training the Model
#     * Evaluating Model Performance
#
# 6. `Making Predictions`
#
# 7. `Saving and Loading the Model`

# %% [markdown]
# **Import Libraries:** 🛠
#
# Let's start the project by importing all the libraries that we will use in this project.

# %%
# import libraries:

# 1. to handel the data:
import numpy as np
import pandas as pd

# 2. to visualize the data:
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# 3. to preprocess the data:
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 4. to build the model:
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

# 5. Metrics:
from sklearn.metrics import accuracy_score, precision_score, recall_score, r2_score, f1_score , classification_report, mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# 6. to ignore the warnings:
import warnings
warnings.filterwarnings("ignore")

print("Libraries have been loaded successfully")

# 8. Display all rows and columns:
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# if you want to see all the rows and columns in the output column, then uncomment the two cells above.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 # import libraries:
#       2
#       3 # 1. to handel the data:
# ----> 4 import numpy as np
#       5 import pandas as pd
#       7 # 2. to visualize the data:
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
#  **But why these libraries?** 🤔

# %% [markdown]
# * `pandas:` For data manipulation and analysis.
#
# * `numpy:` For numerical computations.
#
# * `matplotlib & seaborn:` For data visualization.
#
# * `scikit-learn:` For machine learning algorithms and evaluation metrics.
#
# * `%matplotlib inline:` To display plots directly in the notebook.

# %% [markdown]
# - **Setting up the Visualization Theme**: 🐱‍🏍✨

# %%
# Set the dark blue background theme for visualizations
plt.style.use('dark_background')

# Adjust background color to dark blue
plt.rcParams['figure.facecolor'] = '#0d1b2a'
plt.rcParams['axes.facecolor'] = '#0d1b2a'
plt.rcParams['axes.edgecolor'] = '#0d1b2a'
plt.rcParams['savefig.facecolor'] = '#0d1b2a'

# Define a custom color palette with a golden neon effect
golden_neon_palette = sns.color_palette(["#ffd700", "#ffdf00", "#ffec8b", "#ffec00", "#fff700"])

# Apply the custom palette to Seaborn
sns.set_palette(golden_neon_palette)

# %% [markdown]
# - **Load the dataset**: 📅

# %%
path = '/kaggle/input/stars-dataset/star_dataset.csv'
df = pd.read_csv(path)

# %%
# df = pd.read_csv("star_dataset.csv")

# %% [markdown]
# - Lets have a sneek peak on the data: 👀

# %%
df.head()
# Out:
#              Name  Distance (ly)  Luminosity (L/Lo)  Radius (R/Ro)  \
# 0          Altair      16.594171           9.979192       1.632650
# 1           Deneb    2600.490723      196002.627856     202.970526
# 2  Barnard's Star       6.052616           4.893716       0.222711
# 3         Polaris     322.601002        2196.241934      37.546813
# 4  Barnard's Star       5.902392          -1.496486       0.192359
#
#    Temperature (K) Spectral Class
# 0      7509.294247            A7V
# 1      8503.284796           A2Ia
# 2      3165.959639           M4Ve
# 3      6048.326915           F7Ib
# 4      3130.602069           M4Ve

# %%
df.tail()
# Out:
#                  Name  Distance (ly)  Luminosity (L/Lo)  Radius (R/Ro)  \
# 995          Wolf 359       7.455715          -4.435101       0.068087
# 996             Hadar     350.301644       49997.506591       9.070882
# 997         Bellatrix     239.763294        6397.020159       5.706311
# 998  Alpha Centauri B       4.044364          -4.549088       0.939191
# 999          Wolf 359       8.139786           3.484205       0.236324
#
#      Temperature (K) Spectral Class
# 995      2774.148300            M6V
# 996     25010.502656          B1III
# 997     22603.548766          B2III
# 998      5286.304304            K1V
# 999      2813.600366            M6V

# %% [markdown]
# - checking the information of the dataset: 🔍

# %%
df.columns
# Out:
# Index(['Name', 'Distance (ly)', 'Luminosity (L/Lo)', 'Radius (R/Ro)',
#        'Temperature (K)', 'Spectral Class'],
#       dtype='object')

# %% [markdown]
# - but the above columns are not clear, looks cluttered to me.  🥱
# - So, being a pythonic, I'll arrange them in an order and make them more readable.

# %%
# renaming the columns for better understanding:

df = df.rename(columns={
    'Name': 'Name',
    'Distance (ly)': 'Distance',
    'Luminosity (L/Lo)': 'Luminosity',
    'Radius (R/Ro)': 'Radius',
    'Temperature (K)': 'Temperature',
    'Spectral_Class': 'Spectral Class'
})

# %%
# lets make the column names more readable by using for loop and if condition:
i = 0

for col in df.columns:
    if i == len(df.columns):
        break
    else:
        print(f"Column {i}: {col}")
    i += 1
# Out:
# Column 0: Name
# Column 1: Distance
# Column 2: Luminosity
# Column 3: Radius
# Column 4: Temperature
# Column 5: Spectral Class

# %%
# print the number of columns and rows in the dataset using the shape attribute:

print(f"There are {df.shape[1]} columns and {df.shape[0]} rows in the dataset")
# Out:
# There are 6 columns and 1000 rows in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            1000 non-null   object
#  1   Distance        1000 non-null   float64
#  2   Luminosity      1000 non-null   float64
#  3   Radius          1000 non-null   float64
#  4   Temperature     1000 non-null   float64
#  5   Spectral Class  1000 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 47.0+ KB

# %% [markdown]
# - check for missing values: 🕵️‍♂️

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Name              0
# Distance          0
# Luminosity        0
# Radius            0
# Temperature       0
# Spectral Class    0
# dtype: int64

# %% [markdown]
# - lets check the statistical summary of the dataset: 🧩
#
# (it will only show the numerical columns)

# %%
df.describe()
# Out:
#           Distance     Luminosity       Radius   Temperature
# count  1000.000000    1000.000000  1000.000000   1000.000000
# mean    295.505327   19644.909442    86.960696   9983.486779
# std     541.478403   42223.595017   213.850005   7906.973529
# min       3.877798      -4.993141     0.068087   2750.183163
# 25%      11.716853      10.441039     1.664479   3940.020856
# 50%      52.031435     171.097809     5.845444   7379.007975
# 75%     322.865874   10500.577117    33.719778  12055.975095
# max    2600.490723  196004.854081   887.097936  28044.279272

# %% [markdown]
# ## Observations: 📝
#
# Followings are the observations from the dataset:
#
#
# - The dataset has `6 columns` and `1000 rows`.
# - There are `no missing values` in the dataset.
#
# **Column names are**:
#
# - Name
# - Distance
# - Luminosity
# - Radius
# - Temperature
# - Spectral Class
#
# **Among these columns**:
# - Distance is `numerical` and `continuous`.
# - Luminosity is `numerical` and `continuous`.
# - Radius is `numerical` and `continuous`.
# - Temperature is `numerical` and `continuous`.
#
# - Spectral Class is `categorical` and `ordinal`.
# - Color is `categorical` and `ordinal`.

# %% [markdown]
# ## ✨ Exploratory Data Analysis (EDA): 📊
# - we will go through the data and check each column carefully to get maximum insights possible: 🧐

# %% [markdown]
# ### **1.Name Column:**

# %%
df['Name'].value_counts()
# Out:
# Name
# Altair              74
# Canopus             48
# Ross 154            45
# Hadar               45
# Betelgeuse          44
# Castor              39
# Capella             39
# Arcturus            38
# Vega                38
# Barnard's Star      38
# Mira                37
# Bellatrix           37
# Alnilam             36
# Rigil Kentaurus     36
# Polaris             35
# Sirius              34
# Spica               32
# Fomalhaut           31
# Procyon             30
# Acrux               30
# Achernar            29
# Lalande 21185       27
# Regulus             26
# Antares             26
# Deneb               25
# Alpha Centauri B    24
# Wolf 359            22
# Aldebaran           18
# Rigel               17
# Name: count, dtype: int64

# %%
df['Name'].unique()
# Out:
# array(['Altair', 'Deneb', "Barnard's Star", 'Polaris', 'Sirius',
#        'Fomalhaut', 'Capella', 'Bellatrix', 'Castor', 'Hadar',
#        'Betelgeuse', 'Regulus', 'Mira', 'Acrux', 'Vega', 'Lalande 21185',
#        'Arcturus', 'Alpha Centauri B', 'Ross 154', 'Canopus', 'Procyon',
#        'Wolf 359', 'Antares', 'Alnilam', 'Rigil Kentaurus', 'Spica',
#        'Achernar', 'Aldebaran', 'Rigel'], dtype=object)

# %%
print("The total number of unique Names of stars are: \n", )
for name in df['Name'].unique():
    print(name)
# Out:
# The total number of unique Names of stars are:
#
# Altair
# Deneb
# Barnard's Star
# Polaris
# Sirius
# Fomalhaut
# Capella
# Bellatrix
# Castor
# Hadar
# Betelgeuse
# Regulus
# Mira
# Acrux
# Vega
# Lalande 21185
# Arcturus
# Alpha Centauri B
# Ross 154
# Canopus
# Procyon
# Wolf 359
# Antares
# Alnilam
# Rigil Kentaurus
# Spica
# Achernar
# Aldebaran
# Rigel

# %%
# histogram of name column using seaborn:

plt.figure(figsize=(14, 8))
sns.histplot(data=df, x='Name')
plt.title("Histogram of Name column")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# let's make it interactive using plotly:

# %%
 # make a histogram of name column using plotly express:

plt.figure(figsize=(12, 8))
fig = px.histogram(df, x='Name', title='Histogram of Name column')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
# histogram of name with color spectral class using plotly:

fig = px.histogram(df, x= 'Name', color='Spectral Class', title= 'Histogram of Name with respect to Spectral Class')
fig.show()
# Out:
# <div>                            <div id="9f6096c2-6863-450e-932a-716b08217bca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f6096c2-6863-450e-932a-716b08217bca")) {                    Plotly.newPlot(                        "9f6096c2-6863-450e-932a-716b08217bca",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Spectral Class=A7V\u003cbr\u003eName=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A7V","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"A7V","offsetgroup":"A7V","orientation":"v","showlegend":true,"x":["Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Alt
# ...

# %% [markdown]
# ### **2. Distance Column:**

# %%
# histogram of the Distance column:

plt.figure(figsize=(12, 8))
sns.histplot(df['Distance'], kde=True, color='gold')
plt.title("Histogram of the Distance column")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Distance'], color = 'gold')
plt.title('Boxplot of Distance')
plt.xlabel('Luminosity')
plt.show()

# %%
# histogram of Distance column with respect to Name Class using plotly:

fig = px.histogram(df, x='Distance', color='Name', title='Histogram of Distance with respect to Name')
fig.show()
# Out:
# <div>                            <div id="209e21f5-a8c5-42a7-989c-68420324b6b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("209e21f5-a8c5-42a7-989c-68420324b6b7")) {                    Plotly.newPlot(                        "209e21f5-a8c5-42a7-989c-68420324b6b7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Name=Altair\u003cbr\u003eDistance=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Altair","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Altair","offsetgroup":"Altair","orientation":"v","showlegend":true,"x":[16.59417123707501,16.324631801826886,16.97783483438638,16.481723812762002,17.004752557357463,16.790538913857493,17.114041468810747,16.342681874475897,1
# ...

# %%
df['Distance'].value_counts().sum()
# Out:
# 1000

# %%
df['Distance'].duplicated().sum()
# Out:
# 0

# %%
# round the distance column to 2 decimal places:

print(f"The minimum distance of star from Earth in Light Year is :{df['Distance'].min().round(2)} (light year)")
print(f"The maximum distance of star from Earth in Light Year is :{df['Distance'].max().round(2)} (light year)")
# Out:
# The minimum distance of star from Earth in Light Year is :3.88 (light year)
# The maximum distance of star from Earth in Light Year is :2600.49 (light year)

# %% [markdown]
# ### **3. Luminosity:**

# %%
df['Luminosity'].duplicated().sum()
# Out:
# 0

# %%
df['Luminosity'].describe()
# Out:
# count      1000.000000
# mean      19644.909442
# std       42223.595017
# min          -4.993141
# 25%          10.441039
# 50%         171.097809
# 75%       10500.577117
# max      196004.854081
# Name: Luminosity, dtype: float64

# %% [markdown]
# The minimum luminosity of star is `-4.993141` and maximum luminosity of star is `196004.854081`.
# but which stars have the minimum and maximum luminosity? What are their names? We will find out.

# %% [markdown]
# As the limunosity column has no duplicates, it means it has all unique values.

# %%
# lets check out Luminosity column with respect to Name column: 
df.groupby('Name')['Luminosity'].value_counts().sort_values(ascending=False)
# Out:
# Name       Luminosity
# Achernar   3145.067171    1
# Mira       8701.822618    1
#            8698.019963    1
#            8698.681151    1
#            8698.967658    1
#                          ..
# Bellatrix  6401.369852    1
#            6401.595201    1
#            6401.703523    1
#            6402.532053    1
# Wolf 359   4.928127       1
# Name: count, Length: 1000, dtype: int64

# %%
# lets make histogram of Luminosity column with respect to Name column using matplotlib:

plt.figure(figsize=(12, 9))
plt.hist(df['Luminosity'], bins=20, color='gold')
plt.title("Histogram of Luminosity column")
plt.xlabel("Luminosity")
plt.ylabel("Frequency")
plt.show()

# %%
# lets make a histogram of `Luminosity` column with respect to `Name` column using seaborn:

plt.figure(figsize=(20, 14))
sns.histplot(df, x='Luminosity', hue='Name', kde=True, color='gold')
plt.title("Histogram of Luminosity with respect to Name")
plt.xlabel("Luminosity")
plt.ylabel("Frequency")
plt.show()

# %%
# lets try the same plot using plotly:

fig = plt.figure(figsize=(12, 8))
fig = px.histogram(df, x='Luminosity', color='Name', title='Histogram of Luminosity with respect to Name')
fig.show()
# Out:
# <div>                            <div id="01f99523-2e72-4b18-b55f-b5c430b4b098" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01f99523-2e72-4b18-b55f-b5c430b4b098")) {                    Plotly.newPlot(                        "01f99523-2e72-4b18-b55f-b5c430b4b098",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Name=Altair\u003cbr\u003eLuminosity=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Altair","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Altair","offsetgroup":"Altair","orientation":"v","showlegend":true,"x":[9.979192445462427,10.45707878952248,8.978258642897934,10.654505105436735,15.509653584166164,7.001586190285418,7.967577662722815,14.591181440400176,7.
# ...

# %%
print(f"Deben star has the Maximum Luminosity as compared to Earth and that is :{df['Luminosity'].max().round(2)} (Light year)")
print(f"Earth star has the Minimum Luminosity as compared to Earth and that is :{df['Luminosity'].min().round(2)} (Light year)")
# Out:
# Deben star has the Maximum Luminosity as compared to Earth and that is :196004.85 (Light year)
# Earth star has the Minimum Luminosity as compared to Earth and that is :-4.99 (Light year)

# %% [markdown]
# We have found these stars! 🌌\
# Excited to know? \
# Check out the respective column outputs to find out. 🌟

# %%
# lets see the luminosity column with respect to Distance column:

df.groupby('Distance')[['Name', 'Luminosity']].value_counts().sort_values(ascending=False)
# Out:
# Distance     Name              Luminosity
# 3.877798     Alpha Centauri B  4.036718         1
# 309.771121   Canopus           10499.979018     1
# 309.551568   Canopus           10501.834765     1
# 309.595001   Canopus           10500.971727     1
# 309.595349   Canopus           10501.356418     1
#                                                ..
# 24.595124    Fomalhaut         15.016026        1
# 24.636958    Fomalhaut         19.023125        1
# 24.645194    Vega              35.637090        1
# 24.653906    Vega              41.610427        1
# 2600.490723  Deneb             196002.627856    1
# Name: count, Length: 1000, dtype: int64

# %%
# lets try to make a scatter plot of Luminosity with respect to Distance using matplotlib:

plt.figure(figsize=(12, 8))
plt.scatter(df['Luminosity'], df['Distance'], color='gold')
plt.title("Scatter plot of Luminosity with respect to Distance")
plt.xlabel("Luminosity")
plt.ylabel("Distance")
plt.show()

# %%
# lets try to make a scatter plot of Luminosity with respect to Distance using seaborn:

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='Luminosity', y='Distance', color='gold')
plt.title("Scatter plot of Luminosity with respect to Distance")
plt.xlabel("Luminosity")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# But the scatter plot is not clear, lets try to make a scatter plot using plotly so we can interact with the plot and can see each point clearly:

# %%
# lets try the same plot using plotly:

fig = px.scatter(df, x='Luminosity', y='Distance', color='Name', title='Scatter plot of Luminosity with respect to Distance')
fig.show()
# Out:
# <div>                            <div id="69071e6d-f296-426c-9f19-921607123af3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69071e6d-f296-426c-9f19-921607123af3")) {                    Plotly.newPlot(                        "69071e6d-f296-426c-9f19-921607123af3",                        [{"hovertemplate":"Name=Altair\u003cbr\u003eLuminosity=%{x}\u003cbr\u003eDistance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Altair","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Altair","orientation":"v","showlegend":true,"x":[9.979192445462427,10.45707878952248,8.978258642897934,10.654505105436735,15.509653584166164,7.001586190285418,7.967577662722815,14.591181440400176,7.453787627075437,13.984383744732718,5.9332655074
# ...

# %% [markdown]
# I've found another useful insight:
#
# * The **Deben star** has a luminosity of `2600.49` and  is `196.0026K` lights years away from the Earth.
# * The **Altair star** has a luminosity of `5.68` and is `3.877` lights years away from the Earth.

# %% [markdown]
# ### **4. Radius:**
# The radius of the star relative to the Sun's radius.

# %%
df['Radius'].value_counts().sum()
# Out:
# 1000

# %%
df['Radius'].duplicated().sum()
# Out:
# 0

# %%
# lets check out Radius column with respect to Name column:
df.groupby('Name')['Radius'].max()
# Out:
# Name
# Achernar              9.296362
# Acrux                 8.482459
# Aldebaran            44.271139
# Alnilam              32.488388
# Alpha Centauri B      0.955607
# Altair                1.727955
# Antares             680.094465
# Arcturus             25.496503
# Barnard's Star        0.289792
# Bellatrix             5.847997
# Betelgeuse          887.097936
# Canopus              71.096096
# Capella              12.091995
# Castor                2.494925
# Deneb               203.097136
# Fomalhaut             1.909887
# Hadar                 9.099063
# Lalande 21185         0.485364
# Mira                370.081856
# Polaris              37.599432
# Procyon               2.145289
# Regulus               3.227721
# Rigel                78.977095
# Rigil Kentaurus       1.319765
# Ross 154              0.294127
# Sirius                1.802411
# Spica                 7.496552
# Vega                  2.455010
# Wolf 359              0.257469
# Name: Radius, dtype: float64

# %%
print(f" The minimum radius amoung the stars is {df['Radius'].min()} and it is of `Wolf 359` star")
print(f" The maximum radius amoung the stars is {df['Radius'].max()} and it is of `Betelgeuse` star")
# Out:
#  The minimum radius amoung the stars is 0.068086676942714 and it is of `Wolf 359` star
#  The maximum radius amoung the stars is 887.0979364514885 and it is of `Betelgeuse` star

# %%
# lets make histogram of Radius column with respect to Name column using matplotlib:

plt.figure(figsize=(12, 9))
plt.hist(df['Radius'], bins=20, color='gold')
plt.title("Histogram of Radius column")
plt.xlabel("Radius")
plt.ylabel("Frequency")
plt.show()

# %%
# lets make a histogram of `Radius` column with respect to `Name` column using seaborn:

plt.figure(figsize=(20, 14))
sns.histplot(df, x='Radius', hue='Name', kde=True, color='gold')
plt.title("Histogram of Radius with respect to Name")
plt.xlabel("Radius")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The above plot shows that the Radius of the stars is not same and it varies from star to star.
# now, we will try to make the same plot using plotly, so we can have a better understanding of the data points.FloatingPointError

# %%
# lets try the same plot using plotly:

fig = plt.figure(figsize=(12, 8))
fig = px.histogram(df, x='Radius', color='Name', title='Histogram of Radius with respect to Name')
fig.show()
# Out:
# <div>                            <div id="06fd50ba-08ec-4d38-a68b-2dd3951ef7b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06fd50ba-08ec-4d38-a68b-2dd3951ef7b0")) {                    Plotly.newPlot(                        "06fd50ba-08ec-4d38-a68b-2dd3951ef7b0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Name=Altair\u003cbr\u003eRadius=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Altair","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Altair","offsetgroup":"Altair","orientation":"v","showlegend":true,"x":[1.6326504020392336,1.6385681357721884,1.6817677393535218,1.697977233932925,1.5741356101164594,1.619005689841054,1.6666693118467406,1.6839372242618915,1.5
# ...

# %%
# lets check the `radius` column with respect to the `luminosity` column:

df.groupby('Luminosity')[['Name', 'Radius']].value_counts().sort_values(ascending=False)
# Out:
# Luminosity      Name       Radius
# -4.993141       Wolf 359   0.254853      1
#  8698.681151    Mira       370.060374    1
#  6403.986083    Bellatrix  5.735235      1
#  6404.804362    Bellatrix  5.750253      1
#  8695.087925    Mira       369.998313    1
#                                         ..
#  23.937962      Sirius     1.723720      1
#  24.170119      Sirius     1.626444      1
#  24.461618      Sirius     1.620898      1
#  25.317214      Sirius     1.768243      1
#  196004.854081  Deneb      203.022715    1
# Name: count, Length: 1000, dtype: int64

# %%
# lets try to make a scatter plot of Radius with respect to Luminosity using matplotlib:

plt.figure(figsize=(12, 8))
plt.scatter(df['Radius'], df['Luminosity'], color='gold')
plt.title("Scatter plot of Radius with respect to Luminosity")
plt.xlabel("Radius")
plt.ylabel("Luminosity")
plt.show()

# %%
# lets try the same plot using seaborn:

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='Radius', y='Luminosity', hue='Name', color='gold')
plt.title("Scatter plot of Radius with respect to Luminosity")
plt.xlabel("Radius")
plt.ylabel("Luminosity")
plt.show()

# %% [markdown]
# lets try the same plot using plotly, so we can have a better understanding and we can interact with the data points:

# %%
# lets try the same plot using plotly:

fig = px.scatter(df, x='Radius', y='Luminosity', color='Name', title='Scatter plot of Radius with respect to Luminosity')
fig.show()
# Out:
# <div>                            <div id="89ff2b82-2eb2-48e1-910e-f2862ec3e23a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89ff2b82-2eb2-48e1-910e-f2862ec3e23a")) {                    Plotly.newPlot(                        "89ff2b82-2eb2-48e1-910e-f2862ec3e23a",                        [{"hovertemplate":"Name=Altair\u003cbr\u003eRadius=%{x}\u003cbr\u003eLuminosity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Altair","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Altair","orientation":"v","showlegend":true,"x":[1.6326504020392336,1.6385681357721884,1.6817677393535218,1.697977233932925,1.5741356101164594,1.619005689841054,1.6666693118467406,1.6839372242618915,1.54902109753883,1.5937402895793085,1.6968367572
# ...

# %%
# lets try to group all the columns with respect to Name column:

df.groupby('Name')[['Distance', 'Luminosity', 'Radius']].value_counts().sort_values(ascending=False)
# Out:
# Name       Distance    Luminosity    Radius
# Achernar   143.583774   3154.094333  9.286495      1
# Mira       418.173339   8695.589846  369.926320    1
#            417.739685   8702.983016  370.055858    1
#            417.747362   8699.858563  370.023915    1
#            417.783312   8702.919446  369.969747    1
#                                                   ..
# Bellatrix  240.124736   6398.402468  5.705005      1
#            240.160483   6399.823852  5.650815      1
#            240.308658   6398.706400  5.727505      1
#            240.350552   6403.480527  5.803192      1
# Wolf 359   8.201478    -2.548241     0.186454      1
# Name: count, Length: 1000, dtype: int64

# %% [markdown]
# the above cell shows the group of all the columns I've analyzed with respect to Name column.

# %% [markdown]
# ### 5. Temperature Column:
# represents the surface temperature of the star in `Kelvin`.

# %%
df['Temperature'].value_counts().sum()
# Out:
# 1000

# %%
df['Temperature'].duplicated().sum()
# Out:
# 0

# %%
df['Temperature'].describe()
# Out:
# count     1000.000000
# mean      9983.486779
# std       7906.973529
# min       2750.183163
# 25%       3940.020856
# 50%       7379.007975
# 75%      12055.975095
# max      28044.279272
# Name: Temperature, dtype: float64

# %%
print(f"The minimum temperature of star is {df['Temperature'].min()} (Kelvin)")
print(f"The maximum temperature of star is {df['Temperature'].max()} (Kelvin)")
# Out:
# The minimum temperature of star is 2750.18316322717 (Kelvin)
# The maximum temperature of star is 28044.279271635794 (Kelvin)

# %% [markdown]
# But which are these stars with the minimum and maximum temperature? 🤔\
# we will find out below:

# %%
# lets check the temperature column with respect to Name column:

df.groupby('Name')['Temperature'].value_counts().sort_values(ascending=False)
# Out:
# Name       Temperature
# Achernar   14958.360315    1
# Mira       2925.392076     1
#            2891.915305     1
#            2893.530511     1
#            2896.357311     1
#                           ..
# Bellatrix  22625.863116    1
#            22628.271959    1
#            22628.845404    1
#            22632.467299    1
# Wolf 359   2846.286326     1
# Name: count, Length: 1000, dtype: int64

# %%
# lets make histogram of Temperature column with respect to Name column using matplotlib:

plt.figure(figsize=(12, 9))
plt.hist(df['Temperature'], bins=20, color='gold')
plt.title("Histogram of Temperature column")
plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.show()

# %%
# lets make a histogram of `Temperature` column with respect to `Name` column using seaborn:

plt.figure(figsize=(20, 14))
sns.histplot(df, x='Temperature', hue='Name', kde=True, color='gold')
plt.title("Histogram of Temperature with respect to Name")
plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.show()

# %%
# lets try the same plot using plotly to have a better understanding:

fig = plt.figure(figsize=(12, 8))
fig = px.histogram(df, x='Temperature', color='Name', title='Histogram of Temperature with respect to Name')
fig.show()
# Out:
# <div>                            <div id="372472f4-a2f5-46e1-85e9-989d8ff4ca62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("372472f4-a2f5-46e1-85e9-989d8ff4ca62")) {                    Plotly.newPlot(                        "372472f4-a2f5-46e1-85e9-989d8ff4ca62",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Name=Altair\u003cbr\u003eTemperature=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Altair","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Altair","offsetgroup":"Altair","orientation":"v","showlegend":true,"x":[7509.29424736388,7554.538238404283,7546.77607407146,7557.224465410894,7589.01886160571,7500.178549124861,7589.938436857879,7534.755587192668,7579.28
# ...

# %% [markdown]
# ---
# **Q: Should we convert the temperature of stars from Kelvin to Celsius?** 🌡
# **Answer**: **NO!** The reason is:
#
# *Reason*: Stars' temperatures are typically measured in Kelvin because it's the absolute temperature scale used in scientific contexts, especially in astronomy and physics. Converting the temperatures to Celsius isn't common in astrophysical studies since Kelvin directly relates to the physical properties of stars, like black-body radiation.

# %% [markdown]
# ### **6. Spectral Class:**
# As Spectral Class is our target column, we will analyze deeply.

# %%
df['Spectral Class'].value_counts().sum()
# Out:
# 1000

# %%
df['Spectral Class'].duplicated().sum()
# Out:
# 972

# %%
duplicatd_num = 1000-972
print(f" The number of duplicated values in Spectral Class column are: {duplicatd_num}")
# Out:
#  The number of duplicated values in Spectral Class column are: 28

# %%
# lets make histogram of Spectral class column:

plt.figure(figsize=(18,14))
plt.hist(df['Spectral Class'], bins=80, color='gold')
plt.title("Histogram of Spectral Class column")
plt.xlabel("Spectral Class")
plt.xticks(rotation=90)
plt.ylabel("Frequency")
plt.show()

# %%
# lets make the same plot in seaborn:

plt.figure(figsize=(18,14))
sns.histplot(df['Spectral Class'], kde=True, color='gold')
plt.title("Histogram of Spectral Class column")
plt.xlabel("Spectral Class")
plt.xticks(rotation=90)
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The above plot still seems incomplete and unclear. Lets try the same plot in plotly to have a better understanding.

# %%
fig = plt.figure(figsize=(12, 8))
fig = px.histogram(df, x='Spectral Class', title='Histogram of Spectral Class column')
fig.show()
# Out:
# <div>                            <div id="492c476c-49f3-4588-aadb-f08dc40ddb24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("492c476c-49f3-4588-aadb-f08dc40ddb24")) {                    Plotly.newPlot(                        "492c476c-49f3-4588-aadb-f08dc40ddb24",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Spectral Class=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["A7V","A2Ia","M4Ve","F7Ib","M4Ve","A1V","A3V","G8III","G8III","B2III","A1V","A7V","B2III","B1III","M2Iab","B7V","B7V","M7IIIe","B0.5IV","A0V","M2Iab","M2.1V","B1III","B7V","B7V","B2III","
# ...

# %%
# now we will draw the same plot with respect to the name column:
fig = plt.figure(figsize=(12, 8))
fig = px.histogram(df, x='Spectral Class', color='Name', title='Histogram of Spectral Class with respect to Name')
fig.show()
# Out:
# <div>                            <div id="5044b6fd-1fdc-4b9c-bd93-483debc30507" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5044b6fd-1fdc-4b9c-bd93-483debc30507")) {                    Plotly.newPlot(                        "5044b6fd-1fdc-4b9c-bd93-483debc30507",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Name=Altair\u003cbr\u003eSpectral Class=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Altair","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Altair","offsetgroup":"Altair","orientation":"v","showlegend":true,"x":["A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","A7V","
# ...

# %%
# now we will check which stars classification based on spectral class:

df['Spectral Class'].value_counts().max()
# Out:
# 74

# %% [markdown]
# now we will find which star has the maximum number and which `spectral class` it falls in.

# %%
# To get the spectral class with maximum occurrence
max_spectral_class = df['Spectral Class'].value_counts().idxmax()

# To get the spectral class with minimum occurrence
min_spectral_class = df['Spectral Class'].value_counts().idxmin()

# Display the results
print("Spectral class with maximum occurrences:", max_spectral_class)
print("Spectral class with minimum occurrences:", min_spectral_class)
# Out:
# Spectral class with maximum occurrences: A7V
# Spectral class with minimum occurrences: B8Ia

# %%
# lets check the 'Spectral Class' column with respect to 'Distance' column using groupby:

df.groupby('Spectral Class')['Distance'].max().sort_values(ascending=False)
# Out:
# Spectral Class
# A2Ia        2600.490723
# B0Ia        2000.496809
# B8Ia         860.436400
# M2Iab        642.997230
# M1.5Iab      550.483410
# M7IIIe       418.481250
# B1III        350.482659
# F7Ib         323.489083
# B0.5IV       321.457318
# A9II         310.483900
# B1III-IV     250.487876
# B2III        240.498170
# B6Vep        144.472092
# B7V           79.469050
# K5III         65.470227
# A1V           52.457967
# G8III         43.369766
# K1.5III       37.064926
# A0V           25.482674
# A3V           25.448734
# A7V           17.190193
# F5IV-V        11.856853
# M3.5V         10.175314
# M2.1V          8.787449
# M6V            8.201478
# M4Ve           6.450229
# K1V            4.808568
# G2V            4.770200
# Name: Distance, dtype: float64

# %% [markdown]
# lets draw a few more plots to have a better understanding of the data:

# %%
# now lets check the 'Spectral Class' column with respect to 'Distance' column in plotly:

fig = plt.figure(figsize=(12,8))
fig = px.histogram(df, x='Distance', color='Spectral Class', title='Histogram of Spectral Class with respect to Distance of stars')
fig.show()
# Out:
# <div>                            <div id="3decab50-252c-4106-a4fb-39c876df629e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3decab50-252c-4106-a4fb-39c876df629e")) {                    Plotly.newPlot(                        "3decab50-252c-4106-a4fb-39c876df629e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Spectral Class=A7V\u003cbr\u003eDistance=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A7V","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"A7V","offsetgroup":"A7V","orientation":"v","showlegend":true,"x":[16.59417123707501,16.324631801826886,16.97783483438638,16.481723812762002,17.004752557357463,16.790538913857493,17.114041468810747,16.342681874475897,16.
# ...

# %%
fig = plt.figure(figsize=(12,8))
fig = px.scatter_3d(df, x='Spectral Class', y='Distance', z='Radius', 
                    color='Spectral Class', hover_name='Name',
                    title='Spectral Class vs Distance vs Radius')
fig.show()
# Out:
# <div>                            <div id="b1714a8b-3901-49aa-8856-c40bdf891f8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1714a8b-3901-49aa-8856-c40bdf891f8b")) {                    Plotly.newPlot(                        "b1714a8b-3901-49aa-8856-c40bdf891f8b",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSpectral Class=%{x}\u003cbr\u003eDistance=%{y}\u003cbr\u003eRadius=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair"
# ...

# %%
fig = px.box(df, x='Spectral Class', y='Distance', color='Spectral Class', 
             points="all", hover_name='Name', 
             title='Distribution of Distance by Spectral Class')
fig.show()
# Out:
# <div>                            <div id="26956e06-127e-4ede-a174-0bc0dfd4bca6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26956e06-127e-4ede-a174-0bc0dfd4bca6")) {                    Plotly.newPlot(                        "26956e06-127e-4ede-a174-0bc0dfd4bca6",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSpectral Class=%{x}\u003cbr\u003eDistance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair",
# ...

# %%
fig = px.scatter(df, x='Spectral Class', y='Distance', size='Radius', 
                 color='Spectral Class', hover_name='Name',
                 title='Bubble Chart of Spectral Class vs Distance',
                 size_max=50)
fig.show()
# Out:
# <div>                            <div id="8ec4ed10-8bd5-4c7c-ae93-d85c875965f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ec4ed10-8bd5-4c7c-ae93-d85c875965f9")) {                    Plotly.newPlot(                        "8ec4ed10-8bd5-4c7c-ae93-d85c875965f9",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSpectral Class=%{x}\u003cbr\u003eDistance=%{y}\u003cbr\u003eRadius=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair","Altair
# ...

# %%
fig = px.treemap(df, path=['Spectral Class', 'Name'], values='Radius', 
                 color='Distance', hover_data=['Distance'],
                 title='Treemap of Spectral Class, Name, and Radius')
fig.show()
# Out:
# <div>                            <div id="252e8557-9432-4b63-9355-8b4e2e6fb0a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("252e8557-9432-4b63-9355-8b4e2e6fb0a7")) {                    Plotly.newPlot(                        "252e8557-9432-4b63-9355-8b4e2e6fb0a7",                        [{"branchvalues":"total","customdata":[[144.0786634690464,144.0786634690464],[320.9175560043219,320.9175560043219],[65.02849488258973,65.02849488258973],[2000.0908309353772,2000.0908309353772],[4.259705297667917,4.259705297667917],[16.703435897335606,16.703435897335606],[549.9713954466172,549.9713954466172],[36.60396625617207,36.60396625617207],[5.957291954260371,5.957291954260371],[240.00980079354738,240.00980079354738],[642.5462475635716,642.5462475635716],[310.
# ...

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x='Spectral Class', y='Temperature', data=df)
plt.title('Temperature Distribution by Spectral Class')
plt.ylabel('Temperature')
plt.xlabel('Spectral Class')
plt.show()

# %%
df.head()
# Out:
#              Name     Distance     Luminosity      Radius  Temperature  \
# 0          Altair    16.594171       9.979192    1.632650  7509.294247
# 1           Deneb  2600.490723  196002.627856  202.970526  8503.284796
# 2  Barnard's Star     6.052616       4.893716    0.222711  3165.959639
# 3         Polaris   322.601002    2196.241934   37.546813  6048.326915
# 4  Barnard's Star     5.902392      -1.496486    0.192359  3130.602069
#
#   Spectral Class
# 0            A7V
# 1           A2Ia
# 2           M4Ve
# 3           F7Ib
# 4           M4Ve

# %%
df.describe()
# Out:
#           Distance     Luminosity       Radius   Temperature
# count  1000.000000    1000.000000  1000.000000   1000.000000
# mean    295.505327   19644.909442    86.960696   9983.486779
# std     541.478403   42223.595017   213.850005   7906.973529
# min       3.877798      -4.993141     0.068087   2750.183163
# 25%      11.716853      10.441039     1.664479   3940.020856
# 50%      52.031435     171.097809     5.845444   7379.007975
# 75%     322.865874   10500.577117    33.719778  12055.975095
# max    2600.490723  196004.854081   887.097936  28044.279272

# %% [markdown]
# If we have temperature, we can classify the stars into different categories based on their temperature.\
# Let's create a function that will classify the stars based on their temperature.

# %%
steller_class = {
    "Class": ["O", "B", "A", "F", "G", "K", "M"],
    "Effective temperature": [">= 33,000 ", "10,000–33,000 ", "7,300–10,000 ", "6,000–7,300 ", "5,300–6,000 ", "3,900–5,300 ", "2,300–3,900 "],
    "Vega-relative chromaticity": ["blue", "bluish white", "white", "yellowish white", "yellow", "light orange", "orangish red"],
    "Chromaticity (D65)": ["blue", "deep bluish white", "bluish white", "white", "yellowish white", "pale yellowish orange", "light orangish red"]
}

steller_class_df = pd.DataFrame(steller_class)
steller_class_df
# Out:
#   Class Effective temperature Vega-relative chromaticity  \
# 0     O            >= 33,000                        blue
# 1     B        10,000–33,000                bluish white
# 2     A         7,300–10,000                       white
# 3     F          6,000–7,300             yellowish white
# 4     G          5,300–6,000                      yellow
# 5     K          3,900–5,300                light orange
# 6     M          2,300–3,900                orangish red
#
#       Chromaticity (D65)
# 0                   blue
# 1      deep bluish white
# 2           bluish white
# 3                  white
# 4        yellowish white
# 5  pale yellowish orange
# 6     light orangish red

# %% [markdown]
# - Now from the above table we can see that the spectral class is divided into `7 classes`:
# 1. O
# 2. B
# 3. A
# 4. F
# 5. G
# 6. K
# 7. M

# %% [markdown]
# Based on the above information, we can classify the stars based on their temperature as follows:

# %%
# based on these temperature values we will create a new column in the dataset named "Steller Class" using if elif condition:

def classify_steller_on_temperature(temp):
    if 33000 <= temp <= 50000:
        return 'O'
    elif 10000 <= temp < 33000:
        return 'B'
    elif 7300 <= temp < 10000:
        return 'A'
    elif 6000 <= temp < 7300:
        return 'F'
    elif 5300 <= temp < 6000:
        return 'G'
    elif 3900 <= temp < 5300:
        return 'K'
    elif 2300 <= temp < 3900:
        return 'M'
    else:
        return 'Unknown'

# Apply the function to the dataset
df['Stellar Class'] = df['Temperature'].apply(classify_steller_on_temperature)

# %% [markdown]
# - **NOTE**:
# 1. **Effective temperature:** The effective temperature of a body such as a star or planet is the temperature of a black body that would emit the same total amount of electromagnetic radiation. Effective temperature is often used as an estimate of a body's surface temperature when the body's emissivity curve is not known.
# 2. **Chromaticity:** is an objective specification of the quality of a color regardless of its luminance. Chromaticity consists of two independent parameters, often specified as hue (h) and colorfulness (s), where the latter is alternatively called saturation, chroma, intensity, or excitation.
# 3. **Chromaticity (D65):** A standard illuminant is a theoretical source of visible light with a spectral power distribution that is published. Standard illuminants provide a basis for comparing images or colors recorded under different lighting.

# %% [markdown]
# > Reference: [Spectral Classification](https://en.wikipedia.org/wiki/Stellar_classification)

# %%
df.head()
# Out:
#              Name     Distance     Luminosity      Radius  Temperature  \
# 0          Altair    16.594171       9.979192    1.632650  7509.294247
# 1           Deneb  2600.490723  196002.627856  202.970526  8503.284796
# 2  Barnard's Star     6.052616       4.893716    0.222711  3165.959639
# 3         Polaris   322.601002    2196.241934   37.546813  6048.326915
# 4  Barnard's Star     5.902392      -1.496486    0.192359  3130.602069
#
#   Spectral Class Stellar Class
# 0            A7V             A
# 1           A2Ia             A
# 2           M4Ve             M
# 3           F7Ib             F
# 4           M4Ve             M

# %%
def classify_steller_on_temperature(temp):
    if 30000 <= temp <= 50000:
        return 'O'
    elif 10000 <= temp < 30000:
        return 'B'
    elif 7500 <= temp < 10000:
        return 'A'
    elif 6000 <= temp < 7500:
        return 'F'
    elif 5200 <= temp < 6000:
        return 'G'
    elif 3700 <= temp < 5200:
        return 'K'
    elif 2000 <= temp < 3700:
        return 'M'
    else:
        return 'Unknown'
df['Stellar Class(temp)'] = df['Temperature'].apply(classify_steller_on_temperature)

# %%
# now we will map the "Vega-relative chromaticity" columns values to the "Stellar Class" column:

stellar_class_map = {
    "O": "blue",
    "B": "bluish white",
    "A": "white",
    "F": "yellowish white",
    "G": "yellow",
    "K": "light orange",
    "M": "orangish red"
}

df['Stellar chromaticity'] = df['Stellar Class'].map(stellar_class_map)

# %%
df.head(30)
# Out:
#                 Name     Distance     Luminosity      Radius   Temperature  \
# 0             Altair    16.594171       9.979192    1.632650   7509.294247
# 1              Deneb  2600.490723  196002.627856  202.970526   8503.284796
# 2     Barnard's Star     6.052616       4.893716    0.222711   3165.959639
# 3            Polaris   322.601002    2196.241934   37.546813   6048.326915
# 4     Barnard's Star     5.902392      -1.496486    0.192359   3130.602069
# 5             Sirius     8.370045      25.625363    1.737616   9903.971704
# 6          Fomalhaut    25.423032      19.314803    1.763473   8541.195355
# 7            Capella    42.569578      77.466547   12.015077   4979.492462
# 8            Capella    43.260859      76.753975   11.926446   4907.779549
# 9          Bellatrix   239.864107    6399.344000    5.751379  22573.286177
# 10            Castor    51.570210      59.933642    2.317294  10334.140339
# ...

# %%
# make a sunburst chart of Stellar Class with respect to Name, Temperature and stellar chromaticity:

fig = px.sunburst(df, path=['Stellar Class', 'Name'], title='Sunburst chart of Stellar Class with respect to Name')
fig.show()
# Out:
# <div>                            <div id="b25b32db-1fdf-45c9-9ee4-b67720b2ae8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b25b32db-1fdf-45c9-9ee4-b67720b2ae8f")) {                    Plotly.newPlot(                        "b25b32db-1fdf-45c9-9ee4-b67720b2ae8f",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["B\u002fAchernar","B\u002fAcrux","K\u002fAldebaran","M\u002fAldebaran","B\u002fAlnilam","G\u002fAlpha Centauri B","K\u002fAlpha Centauri B","A\u002fAltair","M\u002fAntares","K\u002fArcturus","M\u002fBarnard's Star","B\u002fBellatrix","M\u002fB
# ...

# %%
# lets check the correlation of the dataset:

# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Generate the correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='viridis')
plt.title("Correlation of the dataset")
plt.show()

# %% [markdown]
# ## Insights from the Space 🕵️‍♂️🛰

# %% [markdown]
# - **Name Column**:
# 1. The name column represents the unique identifiers of stars.
# 2. The name column has `29 unique` star names.
#    - The star Altair has the highest count of `74` having spectral class `A7V`.
#    - The star Rigel has the lowest count of `17` having spectral class `B8la`.
#
# - **Distance Column**:
# 3. The distance column represents the distance of the star from Earth in light-years.
# 4. The distance column has `1000 unique` values.
# 5. The distance column has a minimum value of `3.877` and a maximum value of `2600.49` which means:
#    - The **Altair** star has the minimum distance is `3.877` light-years away from Earth.
#    - The **Deben** star has the maximum distance is `2600.49` light-years away from Earth.
#
# - **Luminosity Column**:
# 6. The luminosity column represents the luminosity of the star compared to that of the Sun.
# 7. The luminosity column has `1000 unique` values.
# 8. The minimum luminosity of star is `-4.993141` and maximum luminosity of star is `196004.854081`
#    - The **Wolf 359** star has the minimum luminosity.
#    - The **Deben** star has the maximum luminosity.
# 9. If we see the distance of **Deben** Star, it has the `maximum distace` among all the other stars, which is  `2600.49` Light years away from the Earth, with a limunosity of `196004.854081`.
# 10. The **Wolf 359** star has the minimum luminosity of `-4.993141` and is `7.831986` light years away from the Earth.
#
# - **Radius Column**:
# 11. The radius column represents the radius of the star relative to the Sun's radius.
# 12. There are `no missing` values in the radius column
# 13. The radius column has `0 duplicated values` which means that all the values in the radius column are `unique`
# 14. The radius column has a `minimum value` of `0.068087` and a `maximum value` of `887.097936`
#     - The minimum value of `0.068087` belongs to **Wolf 359 star**
#     - The maximum value of `887.097936` belongs to **Betelgeuse star**
# 15. The **Betelgeuse star** has the maximum radius of `887.097936` and is `640.73` light years away from the Earth.
#     - It has the luminosity of `125999.823016` as compared to the Sun.
# 16. The **Wolf 359 star** has the minimum radius of `0.068087` and is `7.831986` light years away from the Earth.
#     - It has the luminosity of `-4.993141` as compared to the Sun.
#
# - **Tepmerature Column**:
# 17. The temperature column represents the surface temperature of the star in `Kelvin`.
# 18. The temperature column has `1000 unique` values.
# 19. The `minimum` temperature of star is `2750.18316322717` (Kelvin)
# 20. The `maximum` temperature of star is `28044.279271635794` (Kelvin)
# 21. **Acrux star** has the Highest tempearture of `28044.279272` Kelvin
# 22. **Wolf 359** has the Lowest temperature of `2750.183163` Kelvin
# 23. There are some `gaps in the temperature` and it is clearly visible in the graphs.
# 24. The significant temperature gap is somwhere around `17K, 18K, 19K, 20K , and 21K` Kelvin in the dataset.
#     - This gap is between **Achernar star** and **Bellatrix star**
#
# - **Spectral Class Column**:
# 25. There are `1000 rows` in the spectral class column.
# 26. The spectral class column has `28 duplicated values`.
# 27. The maximum number of stars in the spectral class column are `74`
# 28. The minimum number of stars in the spectra class column are `17`
# 29. Now we have to find which stars they are?
# 30. We have them here:
#     - Spectral class with maximum occurrences: `A7V`
#     - Spectral class with minimum occurrences: `B8Ia`
# 31. The `A7V` star has the `maximum count` in spectral class and it's distance from Earth is `17.190193` ligth years.
# 32. The `B8Ia` star has the `minimum count` in spectral class and it's distance from Earth is `860.436400` ligth years.
#
# - **Feature Engineering**:
#
# 33.  I've created a new column `Steller Class` based on the `Temperature`column according to the reference : [Spectral Classification based on temperature ranges](https://en.wikipedia.org/wiki/Stellar_classification).
# 34.  I've created a new column `Stellar chromaticity` based on the `Steller Class` column.
#
# - **Correlation Matrix**:
#
# 35. The correlation matrix shows the relationship between the variables.
# 36. The correlation matrix shows that the `Distance` and `Luminosity` have a `strong positive correlation` of `0.78` which means that as the distance of the star from Earth increases, the luminosity of the star also increases.
# 37. The correlation matrix shows that the `Radius` and `Luminosity` have a `strong positive correlation` of `0.53` which means that as the radius of the star increases, the luminosity of the star also increases.
# 38. The correlation matrix shows that the `Temperature` and `Distance` have a `mild positive correlation` of `0.32` which means that as the temperature of the star increases, the distance of the star from Earth also increases. *(This is not a strong correlation)*
# 39. The correlation matrix shows that the `Radius` and `Distance` have a `mild positive correlation` of `0.29` which means that as the radius of the star increases, the distance of the star from Earth also increases. *(This is not a strong correlation)*
#
# <br>
# <br>

# %% [markdown]
# ## 🌌 Predition of Stars in the space 👨‍🚀

# %% [markdown]
# Based on the insights provided, here are the concrete conclusions:
#
# # Key Observations and Insights:
#
# 1. **Star Distribution by Name:**
#    - **Altair** is the most common star in the dataset with 74 entries, classified under the spectral class `A7V`.
#    - **Rigel** is the least frequent star, with only 17 occurrences, falling under spectral class `B8la`.
#
# 2. **Distance Insights:**
#    - **Altair** is the closest star to Earth, located just `3.877` light-years away.
#    - **Deben** is the farthest star at a distance of `2600.49` light-years from Earth.
#    - There's a wide range in distances among the stars, from nearby stars to those very distant, providing a diverse dataset for studying star properties across different ranges.
#
# 3. **Luminosity Observations:**
#    - **Wolf 359** has the lowest luminosity at `-4.993141` compared to the Sun, and it is a relatively close star (7.83 light-years away).
#    - **Deben** has the highest luminosity, measured at `196004.854081`, making it one of the brightest stars in the dataset.
#    - A relationship between distance and luminosity is visible, where stars farther from Earth tend to have higher luminosity.
#
# 4. **Radius Observations:**
#    - **Betelgeuse** has the largest radius, measuring `887.097936` times the Sun’s radius, and it's located `640.73` light-years from Earth.
#    - **Wolf 359** has the smallest radius at `0.068087` relative to the Sun, making it a small but relatively close star.
#
# 5. **Temperature Insights:**
#    - **Acrux** is the hottest star in the dataset, with a temperature of `28044.279272` Kelvin.
#    - **Wolf 359** is the coolest star at `2750.183163` Kelvin, further supporting its status as a smaller, less luminous star.
#    - There's a noticeable gap in temperature between stars around `17K` to `21K` Kelvin, particularly between **Achernar** and **Bellatrix**.
#
# 6. **Spectral Class Observations:**
#    - **A7V** is the most common spectral class, representing stars that are closer to Earth (average distance ~17 light-years).
#    - **B8Ia** is the least common spectral class, with stars averaging around `860.43` light-years away.
#
# 7. **Feature Engineering:**
#    - The creation of the `Stellar Class` and `Stellar chromaticity` columns helps in categorizing stars more clearly based on their temperature and chromatic properties.
#    - These new features could provide additional dimensions to explore relationships between temperature, chromaticity, and other star properties.
#
# # **Strong Conclusions**:
#
# 1. **Luminosity and Distance Correlation:**
#    - A **strong positive correlation** (`0.78`) between **distance** and **luminosity** indicates that as stars get farther from Earth, they tend to have higher luminosity. This suggests that many of the more distant stars are also more massive and luminous.
#
# 2. **Radius and Luminosity Correlation:**
#    - A **strong positive correlation** (`0.53`) between **radius** and **luminosity** implies that larger stars are more luminous. This fits well with the stellar evolution theory, where larger stars tend to emit more light due to their greater surface area and energy output.
#
# 3. **Temperature and Distance:**
#    - A **mild positive correlation** (`0.32`) between **temperature** and **distance** suggests that hotter stars tend to be farther away from Earth. This could indicate that nearby stars are typically cooler, possibly due to being older or less massive.
#
# 4. **Radius and Distance:**
#    - A **mild positive correlation** (`0.29`) between **radius** and **distance** shows that larger stars are generally found farther away. This might be because larger stars, like supergiants, are rarer and tend to be observed at greater distances.
#
# 5. **Wolf 359 as an Outlier:**
#    - **Wolf 359** stands out as an outlier in multiple aspects:
#      - It has the smallest radius, lowest luminosity, and lowest temperature, yet it is relatively close to Earth.
#      - This makes it a prime candidate for detailed study as a low-mass, low-luminosity star, providing insight into small stellar objects.
#
# 6. **Deben Star as a Powerhouse:**
#    - **Deben** is remarkable for its distance and luminosity, being both the farthest and the most luminous star in the dataset. Its characteristics can offer insights into the life cycle of massive, bright stars.
#
# 7. **Temperature Gaps:**
#    - The temperature gaps observed between **Achernar** and **Bellatrix** suggest certain temperature ranges may have fewer stars, possibly indicating stellar evolution stages where stars are not as commonly found.
#
# **Final Thoughts**:
# These conclusions provide a strong basis for understanding the dataset's stars in terms of their physical properties like distance, luminosity, radius, and temperature. Further analysis could focus on specific star groups or investigate outliers like **Wolf 359** and **Deben** to uncover more details about stellar evolution.

# %% [markdown]
# ---
#
# - If you have any questions or suggestions, feel free to ask me.
#
# - Thanks for reading.
#
# - If you like this notebook, `give an upvote`. ([Kaggle](https://www.kaggle.com/faizanyousafonly/))
#
# - If you want to see more of these, `follow me`. ([Kaggle](https://www.kaggle.com/faizanyousafonly/))
#
# ---

# %% [markdown]
# Author: [Muhammad Faizan](https://www.linkedin.com/in/mrfaizanyousaf/)
#
#
# ### 🌐 Connect with Me
#
# [Kaggle](https://www.kaggle.com/faizanyousafonly/) | [LinkedIn](https://www.linkedin.com/in/mrfaizanyousaf/) | [GitHub](https://github.com/faizan-yousaf/)
#
#
#
#
# ### 💬 Contact Me
# - **Email:** faizanyousaf815@gmail.com
# - **WhatsApp:** [+92 306 537 5389](https://wa.me/923065375389)
#
#
# 🔗 **Let’s Collaborate:**
# I'm always open to queries, collaborations, and discussions. Let's build something amazing together!

# %% [markdown]
# ---
#
# # THE END......
#
# ---
